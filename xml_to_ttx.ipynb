# %% [markdown]
# ## 과자 이미지 데이터 전처리

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RLPJ93P3eFeg0Vb1gRAd")
project = rf.workspace("objectdetection-h5xud").project("snacks-usgql")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to snacks-1 in yolov5pytorch:: 100%|██████████| 3841/3841 [00:01<00:00, 2846.92it/s]

# %%
import torch

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
    
print("Using PyTorch version:", torch.__version__, 'Device:', DEVICE)
# Out:
# Using PyTorch version: 2.1.2+cu118 Device: cuda

# %%
import yaml

with open('./snacks-1/data.yaml', 'r') as f:
    data = yaml.full_load(f)
    display(data)
# Out:
# {'names': ['Haetae-PockyBlueberry',
#   'Crown-Choco',
#   'KkokkalkonSavorytaste',
#   'Nongshim-BananaKick',
#   'Nongshim-SquidHouse',
#   'Nongshim-SpicyShrimpCrackers',
#   'Lotte-XylitolBetaVita'],
#  'nc': 7,
#  'roboflow': {'license': 'CC BY 4.0',
#   'project': 'snacks-usgql',
#   'url': 'https://universe.roboflow.com/objectdetection-h5xud/snacks-usgql/dataset/1',
#   'version': 1,
#   'workspace': 'objectdetection-h5xud'},
#  'test': '../test/images',
#  'train': 'C:\\Users\\leeej\\App_for_Blind\\snacks-1\\train.txt',
#  'val': 'C:\\Users\\leeej\\App_for_Blind\\snacks-1\\val.txt'}

# %%
from glob import glob

train_img_list = glob('C:\\Users\\leeej\\App_for_Blind\\snacks-1\\train\\images\\*.jpg')
print(len(train_img_list))
print(train_img_list)

valid_img_list = glob('C:\\Users\\leeej\\App_for_Blind\\snacks-1\\valid\\images\\*.jpg')
print(len(valid_img_list))
# Out:
# 1677
# ...

# %%
with open('./snacks-1/train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')
with open('./snacks-1/val.txt', 'w') as f:
    f.write('\n'.join(valid_img_list) + '\n')

# %%
data['train'] = 'C:\\Users\\leeej\\App_for_Blind\\snacks-1\\train.txt'
data['val'] = 'C:\\Users\\leeej\\App_for_Blind\\snacks-1\\val.txt'

with open('./snacks-1/data.yaml', 'w') as f:
    yaml.dump(data, f)
    display(data)
# Out:
# {'names': ['Haetae-PockyBlueberry',
#   'Crown-Choco',
#   'KkokkalkonSavorytaste',
#   'Nongshim-BananaKick',
#   'Nongshim-SquidHouse',
#   'Nongshim-SpicyShrimpCrackers',
#   'Lotte-XylitolBetaVita'],
#  'nc': 7,
#  'roboflow': {'license': 'CC BY 4.0',
#   'project': 'snacks-usgql',
#   'url': 'https://universe.roboflow.com/objectdetection-h5xud/snacks-usgql/dataset/1',
#   'version': 1,
#   'workspace': 'objectdetection-h5xud'},
#  'test': '../test/images',
#  'train': 'C:\\Users\\leeej\\App_for_Blind\\snacks-1\\train.txt',
#  'val': 'C:\\Users\\leeej\\App_for_Blind\\snacks-1\\val.txt'}

# %%
names = ['해태포키블루베리', '크라운초코', '꼬깔콘고소한맛', '농심바나나킥', '농심오징어집', '농심매운새우깡', '롯데자일리톨베타비타']

# utf-8 인코딩으로 변환
names = [name.encode("utf-8") for name in names]

names
# Out:
# [b'\xed\x95\xb4\xed\x83\x9c\xed\x8f\xac\xed\x82\xa4\xeb\xb8\x94\xeb\xa3\xa8\xeb\xb2\xa0\xeb\xa6\xac',
#  b'\xed\x81\xac\xeb\x9d\xbc\xec\x9a\xb4\xec\xb4\x88\xec\xbd\x94',
#  b'\xea\xbc\xac\xea\xb9\x94\xec\xbd\x98\xea\xb3\xa0\xec\x86\x8c\xed\x95\x9c\xeb\xa7\x9b',
#  b'\xeb\x86\x8d\xec\x8b\xac\xeb\xb0\x94\xeb\x82\x98\xeb\x82\x98\xed\x82\xa5',
#  b'\xeb\x86\x8d\xec\x8b\xac\xec\x98\xa4\xec\xa7\x95\xec\x96\xb4\xec\xa7\x91',
#  b'\xeb\x86\x8d\xec\x8b\xac\xeb\xa7\xa4\xec\x9a\xb4\xec\x83\x88\xec\x9a\xb0\xea\xb9\xa1',
#  b'\xeb\xa1\xaf\xeb\x8d\xb0\xec\x9e\x90\xec\x9d\xbc\xeb\xa6\xac\xed\x86\xa8\xeb\xb2\xa0\xed\x83\x80\xeb\xb9\x84\xed\x83\x80']

# %%
data['names'] = names
with open("./snacks-1/data.yaml", 'w') as f:
    yaml.dump(data, f)
    display(data)
# Out:
# {'names': [b'\xed\x95\xb4\xed\x83\x9c\xed\x8f\xac\xed\x82\xa4\xeb\xb8\x94\xeb\xa3\xa8\xeb\xb2\xa0\xeb\xa6\xac',
#   b'\xed\x81\xac\xeb\x9d\xbc\xec\x9a\xb4\xec\xb4\x88\xec\xbd\x94',
#   b'\xea\xbc\xac\xea\xb9\x94\xec\xbd\x98\xea\xb3\xa0\xec\x86\x8c\xed\x95\x9c\xeb\xa7\x9b',
#   b'\xeb\x86\x8d\xec\x8b\xac\xeb\xb0\x94\xeb\x82\x98\xeb\x82\x98\xed\x82\xa5',
#   b'\xeb\x86\x8d\xec\x8b\xac\xec\x98\xa4\xec\xa7\x95\xec\x96\xb4\xec\xa7\x91',
#   b'\xeb\x86\x8d\xec\x8b\xac\xeb\xa7\xa4\xec\x9a\xb4\xec\x83\x88\xec\x9a\xb0\xea\xb9\xa1',
#   b'\xeb\xa1\xaf\xeb\x8d\xb0\xec\x9e\x90\xec\x9d\xbc\xeb\xa6\xac\xed\x86\xa8\xeb\xb2\xa0\xed\x83\x80\xeb\xb9\x84\xed\x83\x80'],
#  'nc': 7,
#  'roboflow': {'license': 'CC BY 4.0',
#   'project': 'snacks-usgql',
#   'url': 'https://universe.roboflow.com/objectdetection-h5xud/snacks-usgql/dataset/1',
#   'version': 1,
#   'workspace': 'objectdetection-h5xud'},
#  'test': '../test/images',
#  'train': 'C:\\Users\\leeej\\App_for_Blind\\snacks-1\\train.txt',
# ...
